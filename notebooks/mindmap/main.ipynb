# %%
import pandas as pd
from keybert import KeyBERT
from sentence_transformers import SentenceTransformer
import networkx as nx
from pyvis.network import Network

# %%
quran = pd.read_csv('../../data/quran/translations/english/abdullah-yusuf-ali.csv')
quran = quran.head(10)

# %%
kw_model = KeyBERT('all-MiniLM-L6-v2')
# Out:
# d:\projects\machine-learning-lab\.venv\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\localhost\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)

# %%
quran['keywords'] = quran['text'].apply(lambda x: [kw[0] for kw in kw_model.extract_keywords(x, top_n=3)])

# %%
quran.head()
# Out:
#    id                                               text  foot_notes  \
# 0   1  In the name of Allah, Most Gracious, Most Merc...         NaN
# 1   2  Praise be to Allah, the Cherisher and Sustaine...         NaN
# 2   3                      Most Gracious, Most Merciful;         NaN
# 3   4                     Master of the Day of Judgment.         NaN
# 4   5         Thee do we worship, and Thine aid we seek.         NaN
#
#                       keywords
# 0  [allah, merciful, gracious]
# 1   [praise, allah, cherisher]
# 2         [merciful, gracious]
# 3      [judgment, master, day]
# 4         [worship, thee, aid]

# %%
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
texts = quran['text'].tolist()
