# %% [markdown]
# ## Step 1: Reading Data From CSV

# %%
import pandas as pd

df = pd.read_csv('../data/salary-experience-dataset.csv')
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %% [markdown]
# ## Step 2: Splitting Data Into Training & Testing Data

# %%
from sklearn.model_selection import train_test_split

x = df[['YearsExperience']]
y = df['Salary']

(x_train, x_test, y_train, y_test) = train_test_split(x, y, test_size=0.2, random_state=0)

x_train.head()
y_train.head()
# Out:
# 27    112636.0
# 11     55795.0
# 17     83089.0
# 22    101303.0
# 5      56643.0
# Name: Salary, dtype: float64

# %% [markdown]
# ## Step 3: Model Training

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
lr = model.fit(x_train, y_train)

# %% [markdown]
# ## Step 3: Visualize Data

# %%
import matplotlib.pyplot as plt

plt.scatter(x_train, y_train)
plt.plot(x_train, lr.predict(x_train), color='red')
plt.xlabel('Year')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(x_test, y_test)
plt.plot(x_test, lr.predict(x_test), color='red')
plt.xlabel('Year')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Step 5: Testing / Evaluating

# %%
model.score(x_test, y_test)
# Out:
# 0.988169515729126

# %%
model.score(x_train, y_train)
# Out:
# 0.9411949620562127

# %% [markdown]
# ## Step 6: Prediction

# %%
lr.predict([[10]])
# Out:
# /Users/mubashirrr/projects/machine-learning-lab/.venv/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([118975.59290525])
